# %% [markdown]
# # Performance Analytics
#
# This notebook presents the performance analysis of mutual funds using:
#
# - CAGR
# - Sharpe Ratio
# - Sortino Ratio
# - Alpha & Beta
# - Maximum Drawdown
# - Fund Scorecard
# - Benchmark Comparison

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
alpha_beta = pd.read_csv(
    "../data/processed/alpha_beta.csv"
)

alpha_beta.head()
# Out:
#    amfi_code   alpha    beta
# 0     100016  0.0375 -0.0583
# 1     100025  0.0428  0.0012
# 2     100033  0.2720  0.0051
# 3     101206  0.2140  0.0211
# 4     101207  0.1090 -0.0653

# %%
drawdown = pd.read_csv(
    "../data/processed/max_drawdown.csv"
)

drawdown.head()
# Out:
#    amfi_code  max_drawdown_pct
# 0     100016            -24.73
# 1     100025             -4.31
# 2     100033            -16.22
# 3     101206            -11.29
# 4     101207            -35.45

# %%
from IPython.display import Image

Image(
    "../reports/benchmark_comparison.png"
)

# %% [markdown]
# # Key Findings
#
# 1. Top-ranked funds achieved superior risk-adjusted returns.
# 2. Alpha values indicate several funds outperformed the benchmark.
# 3. Drawdown analysis highlights risk differences across funds.
# 4. Sharpe and Sortino ratios helped identify consistent performers.
# 5. The final scorecard combines return and risk metrics for ranking.
